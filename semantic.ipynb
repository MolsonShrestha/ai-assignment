# %%
import nltk
from nltk.corpus import wordnet as wn

# Download WordNet data
nltk.download('wordnet')
nltk.download('omw-1.4')  # Optional: For additional languages

# Word to analyze
word = "car"

# Find all the synsets (senses) of the word
synsets = wn.synsets(word)
print(f"Synsets of the word '{word}':")
for synset in synsets:
    print(synset)

synset = synsets[0]
print(f"\nDefinition of '{word}': {synset.definition()}")
print(f"Example sentence: {synset.examples()}")

# Find synonyms (lemmas)
synonyms = synset.lemma_names()
print(f"\nSynonyms of '{word}': {synonyms}")

# Find hypernyms (broader category)
hypernyms = synset.hypernyms()
print(f"\nHypernyms of '{word}' (broader categories): {hypernyms}")
# Out:
# Synsets of the word 'car':
# Synset('car.n.01')
# Synset('car.n.02')
# Synset('car.n.03')
# Synset('car.n.04')
# Synset('cable_car.n.01')
#
# Definition of 'car': a motor vehicle with four wheels; usually propelled by an internal combustion engine
# Example sentence: ['he needs a car to get to work']
#
# Synonyms of 'car': ['car', 'auto', 'automobile', 'machine', 'motorcar']
#
# Hypernyms of 'car' (broader categories): [Synset('motor_vehicle.n.01')]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
